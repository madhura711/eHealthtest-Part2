# %%
import os
import pandas as pd
import numpy as np

# %%
rates = 'C:\Job Hunt\EHealth Test\Health Insurance Marketplace Dataset\\Rate_fixed.csv'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-6ac8a49e3690> in <module>()
# ----> 1 rates.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
##Data Cleaning##
rates.drop('RowNumber', inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-0d1112217cc5> in <module>()
#       1 ##Data Cleaning##
# ----> 2 rates.drop('RowNumber', inplace=True, axis=1)
#
# AttributeError: 'str' object has no attribute 'drop'

# %%
rates.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-6ac8a49e3690> in <module>()
# ----> 1 rates.head()
#
# AttributeError: 'str' object has no attribute 'head'

# %%
##Variable creation - Age Group##

##Plot of Age vs Individual Plan Rate##
import matplotlib.pyplot as plt
x1 = rates['Age']
y1 = rates['IndividualRate']
x2 = rates['AgeGroup']##

plt.plot(x1,y1)

##plt.plot(x,y2)##
